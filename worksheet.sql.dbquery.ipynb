-- %%
CREATE TABLE dim_stock (
    Ticker STRING,
    Open DOUBLE,
    High DOUBLE,
    Low DOUBLE,
    Close DOUBLE,
    Volume BIGINT,
    eff_start_date date,
    eff_end_date date,
    dw_load_tmp TIMESTAMP,
    dw_upd_load_tmp TIMESTAMP,
    is_active BOOLEAN
)
USING DELTA
PARTITIONED BY (is_active);

drop table dim_stock;

truncate table dim_stock;

select * from dim_stock order by Ticker,eff_start_date;
